# %%
import pandas as pd
import requests
import time
from datetime import datetime

def log(msg):
    print(f"[{datetime.now()}] {msg}")

# ----------- Paths & File Names -----------
MASTER_PATH       = "steam_games_with_owners_parsed.csv"
CLEANED_APPIDS_PATH = "steam_appids_clean.csv"  # contains columns “appid” and “name”
LOG_PATH          = "steam_games_merge_log.txt"
BATCH_SIZE        = 1700

# ----------- Step 1: Sample App IDs -----------
log("STEP 1: Sampling random App IDs from cleaned list...")
app_df = pd.read_csv(CLEANED_APPIDS_PATH)
log(f"  → Loaded {len(app_df)} total App IDs.")
sample_df = app_df.sample(n=BATCH_SIZE, random_state=int(time.time())).reset_index(drop=True)
log(f"  → Sampled {len(sample_df)} App IDs: {list(sample_df['appid'])[:10]}...")

# ----------- Step 2: Fetch Steam Storefront Data -----------
log("STEP 2: Fetching Steam storefront data for sampled App IDs...")
app_ids = sample_df["appid"].astype(int).tolist()
steam_rows = []
MAX_RETRIES = 2
INITIAL_WAIT = 2  # seconds

for idx, app_id in enumerate(app_ids, start=1):
    log(f"  [{idx}/{len(app_ids)}] Fetching Steam info for App ID {app_id}...")
    retry = 0
    success = False
    while retry < MAX_RETRIES and not success:
        try:
            url = f"https://store.steampowered.com/api/appdetails?appids={app_id}&cc=us&l=en"
            resp = requests.get(url, timeout=10)
            resp.raise_for_status()
            data = resp.json()
            if str(app_id) in data and data[str(app_id)].get("success"):
                info = data[str(app_id)]["data"]
                if info.get("type") == "game":
                    steam_rows.append({
                        "app_id": app_id,
                        "name": info.get("name"),
                        "type": info.get("type"),
                        "short_description": info.get("short_description"),
                        "release_date": info.get("release_date", {}).get("date"),
                        "required_age": info.get("required_age"),
                        "price_initial": (info.get("price_overview", {}).get("initial", 0) / 100)
                                         if info.get("price_overview") else None,
                        "price_final": (info.get("price_overview", {}).get("final", 0) / 100)
                                       if info.get("price_overview") else None,
                        "discount_percent": info.get("price_overview", {}).get("discount_percent")
                                            if info.get("price_overview") else None,
                        "platforms_windows": info.get("platforms", {}).get("windows"),
                        "platforms_mac": info.get("platforms", {}).get("mac"),
                        "platforms_linux": info.get("platforms", {}).get("linux"),
                        "genres": ", ".join([g["description"] for g in info.get("genres", [])]),
                        "categories": ", ".join([c["description"] for c in info.get("categories", [])]),
                        "metacritic_score": info.get("metacritic", {}).get("score"),
                        "recommendations_total": info.get("recommendations", {}).get("total"),
                        "developers": ", ".join(info.get("developers", [])),
                        "publishers": ", ".join(info.get("publishers", [])),
                        "screenshots_count": len(info.get("screenshots", [])),
                        "movies_count": len(info.get("movies", [])),
                        "dlc_count": len(info.get("dlc", [])),
                        "steam_url": f"https://store.steampowered.com/app/{app_id}/"
                    })
                    log(f"    ✓ Added game '{info.get('name')}'.")
                else:
                    log(f"    ✗ Skipped App ID {app_id} (type={info.get('type')}).")
                success = True
            else:
                log(f"    ✗ No valid data for App ID {app_id}.")
                success = True
        except requests.exceptions.RequestException as e:
            wait = INITIAL_WAIT * (2 ** retry)
            retry += 1
            log(f"    ! Retry {retry}/{MAX_RETRIES} for App ID {app_id} after {wait}s due to: {e}")
            time.sleep(wait)
        except Exception as e:
            log(f"    ! Non-retryable error for App ID {app_id}: {e}")
            break
    time.sleep(1.5)

steam_df = pd.DataFrame(steam_rows)
log(f"  → Completed Steam fetch: {len(steam_df)} records out of {len(app_ids)}.")

# ----------- Step 3: Fetch SteamSpy Data -----------
log("STEP 3: Fetching SteamSpy data for those games...")
steamspy_fields = [
    "name", "developer", "publisher", "score_rank",
    "positive", "negative", "average_playtime", "median_playtime",
    "owners", "owners_low", "owners_high", "owners_mid",
    "players_forever", "players_2weeks", "ccu"
]
for field in steamspy_fields:
    steam_df[f"steamspy_{field}"] = pd.NA

def parse_owners(owners_str):
    try:
        low_s, high_s = owners_str.split("-")
        low = int(low_s)
        high = int(high_s)
        mid = (low + high) // 2
        return low, high, mid
    except:
        return None, None, None

for idx, app_id in enumerate(steam_df["app_id"].astype(int), start=1):
    log(f"  [{idx}/{len(steam_df)}] Fetching SteamSpy info for App ID {app_id}...")
    try:
        url = f"https://steamspy.com/api.php?request=appdetails&appid={app_id}"
        resp = requests.get(url, timeout=10)
        resp.raise_for_status()
        data = resp.json()
        if data and int(data.get("appid", -1)) == app_id:
            steam_df.at[idx-1, "steamspy_name"] = data.get("name")
            steam_df.at[idx-1, "steamspy_developer"] = data.get("developer")
            steam_df.at[idx-1, "steamspy_publisher"] = data.get("publisher")
            steam_df.at[idx-1, "steamspy_score_rank"] = data.get("score_rank")
            steam_df.at[idx-1, "steamspy_positive"] = data.get("positive")
            steam_df.at[idx-1, "steamspy_negative"] = data.get("negative")
            steam_df.at[idx-1, "steamspy_average_playtime"] = data.get("average_playtime")
            steam_df.at[idx-1, "steamspy_median_playtime"] = data.get("median_playtime")
            owners = data.get("owners", "")
            steam_df.at[idx-1, "steamspy_owners"] = owners
            low, high, mid = parse_owners(owners or "")
            steam_df.at[idx-1, "steamspy_owners_low"] = low
            steam_df.at[idx-1, "steamspy_owners_high"] = high
            steam_df.at[idx-1, "steamspy_owners_mid"] = mid
            steam_df.at[idx-1, "steamspy_players_forever"] = data.get("players_forever")
            steam_df.at[idx-1, "steamspy_players_2weeks"] = data.get("players_2weeks")
            steam_df.at[idx-1, "steamspy_ccu"] = data.get("ccu")
            log("    ✓ SteamSpy data appended.")
        else:
            log("    ✗ No SteamSpy data returned.")
    except Exception as e:
        log(f"    ! ERROR fetching SteamSpy for App ID {app_id}: {e}")
    time.sleep(1.5)

# ----------- Step 4: One-hot Encoding Based on Master’s Columns -----------
log("STEP 4: One-hot encoding 'genres' and 'categories' based on master dataset structure...")

# Load master and ensure 'app_id' is int
master_df = pd.read_csv(MASTER_PATH)
master_df["app_id"] = master_df["app_id"].astype(int)
steam_df["app_id"] = steam_df["app_id"].astype(int)
log(f"  → Master has {len(master_df)} rows; this batch has {len(steam_df)} rows.")

# Detect existing one-hot columns in MASTER
GENRE_LABELS = [col.replace("genres_", "") for col in master_df.columns if col.startswith("genres_")]
CATEGORY_LABELS = [col.replace("categories_", "") for col in master_df.columns if col.startswith("categories_")]
log(f"  → Detected {len(GENRE_LABELS)} genre labels: {GENRE_LABELS[:5]}...")
log(f"  → Detected {len(CATEGORY_LABELS)} category labels: {CATEGORY_LABELS[:5]}...")

# One-hot encode STEAM batch according to those labels
def encode_batch(df, label_list, col, prefix):
    for lbl in label_list:
        cname = f"{prefix}_{lbl}"
        df[cname] = df[col].fillna("").apply(lambda x, lbl=lbl: int(lbl in [s.strip() for s in x.split(",")]))
    return df

steam_encoded = steam_df.copy()
log("  → One-hot encoding genres for batch...")
steam_encoded = encode_batch(steam_encoded, GENRE_LABELS, "genres", "genres")
log("  → One-hot encoding categories for batch...")
steam_encoded = encode_batch(steam_encoded, CATEGORY_LABELS, "categories", "categories")

# Drop raw 'genres' and 'categories' columns from batch
steam_encoded = steam_encoded.drop(columns=["genres", "categories"], errors="ignore")
log("  → Dropped raw 'genres' and 'categories' from batch after encoding.")

# Ensure MASTER has all columns from batch (fill missing with zeros)
log("  → Aligning batch columns to master...")
for col in master_df.columns:
    if col not in steam_encoded.columns:
        steam_encoded[col] = 0
        log(f"    → Added missing batch column '{col}' with zeros.")
# Ensure BATCH columns added to MASTER if missing (fill master with zeros)
for col in steam_encoded.columns:
    if col not in master_df.columns:
        master_df[col] = 0
        log(f"    → Added missing master column '{col}' with zeros.")
# Reorder steam_encoded to match master_df's column order
steam_encoded = steam_encoded[master_df.columns]
log("  → Column alignment complete.")

# ----------- Step 5: Merge and Log Changes -----------
log("STEP 5: Merging new batch into master and logging changes...")

existing_ids = set(master_df["app_id"].tolist())
new_mask = ~steam_encoded["app_id"].isin(existing_ids)
new_rows_df = steam_encoded[new_mask].copy()

before = len(master_df)
added = len(new_rows_df)
log(f"  → {added} new unique App IDs to add: {list(new_rows_df['app_id'])[:10]}...")

# Concatenate and dedupe
combined = pd.concat([master_df, new_rows_df], ignore_index=True)
combined = combined.drop_duplicates(subset="app_id").sort_values(by="app_id").reset_index(drop=True)
combined.to_csv(MASTER_PATH, index=False)
log(f"  → Master CSV updated: {before} → {len(combined)} rows (+{added}).")

# Append summary to log file
with open(LOG_PATH, "a") as logf:
    logf.write(f"\n=== {datetime.now()} ===\n")
    logf.write(f"Rows before merge: {before}\n")
    logf.write(f"Rows after merge:  {len(combined)}\n")
    logf.write(f"App IDs added this run: {list(new_rows_df['app_id'])}\n")
    logf.write("-" * 50 + "\n")

log(f"  → Merge changes recorded to '{LOG_PATH}'.")
# Out:
# [2025-06-03 17:23:13.291720] STEP 1: Sampling random App IDs from cleaned list...
# [2025-06-03 17:23:13.563305]   → Loaded 249007 total App IDs.
# [2025-06-03 17:23:13.569416]   → Sampled 1700 App IDs: [2297834, 3007300, 2222400, 2117110, 1254030, 1570840, 2475900, 597402, 2994470, 906130]...
# [2025-06-03 17:23:13.569416] STEP 2: Fetching Steam storefront data for sampled App IDs...
# [2025-06-03 17:23:13.570404]   [1/1700] Fetching Steam info for App ID 2297834...
# [2025-06-03 17:23:13.802025]     ✗ Skipped App ID 2297834 (type=dlc).
# [2025-06-03 17:23:15.302419]   [2/1700] Fetching Steam info for App ID 3007300...
# [2025-06-03 17:23:15.565298]     ✗ Skipped App ID 3007300 (type=demo).
# [2025-06-03 17:23:17.068669]   [3/1700] Fetching Steam info for App ID 2222400...
# [2025-06-03 17:23:17.353718]     ✓ Added game 'Neighbors: Suburban Warfare - Playtest'.
# [2025-06-03 17:23:18.856743]   [4/1700] Fetching Steam info for App ID 2117110...
# [2025-06-03 17:23:19.090331]     ✓ Added game 'Trail of Toads'.
# [2025-06-03 17:23:20.602604]   [5/1700] Fetching Steam info for App ID 1254030...
# [2025-06-03 17:23:20.907555]     ✗ Skipped App ID 1254030 (type=music).
# [2025-06-03 17:23:22.411413]   [6/1700] Fetching Steam info for App ID 1570840...
# [2025-06-03 17:23:22.584627]     ✓ Added game 'Tides of Tethys'.
# [2025-06-03 17:23:24.086430]   [7/1700] Fetching Steam info for App ID 2475900...
# [2025-06-03 17:23:24.332705]     ✗ Skipped App ID 2475900 (type=dlc).
# [2025-06-03 17:23:25.840384]   [8/1700] Fetching Steam info for App ID 597402...
# [2025-06-03 17:23:26.039232]     ✗ Skipped App ID 597402 (type=episode).
# [2025-06-03 17:23:27.541225]   [9/1700] Fetching Steam info for App ID 2994470...
# [2025-06-03 17:23:27.809916]     ✗ Skipped App ID 2994470 (type=dlc).
# [2025-06-03 17:23:29.313618]   [10/1700] Fetching Steam info for App ID 906130...
# [2025-06-03 17:23:29.593501]     ✗ Skipped App ID 906130 (type=dlc).
# [2025-06-03 17:23:31.108162]   [11/1700] Fetching Steam info for App ID 1017630...
# [2025-06-03 17:23:31.805524]     ✓ Added game 'Robot King Part 2: Boss Battles'.
# [2025-06-03 17:23:33.306966]   [12/1700] Fetching Steam info for App ID 2308610...
# [2025-06-03 17:23:33.534814]     ✗ Skipped App ID 2308610 (type=dlc).
# [2025-06-03 17:23:35.035500]   [13/1700] Fetching Steam info for App ID 3113230...
# [2025-06-03 17:23:35.266060]     ✓ Added game 'Immortal IDLE'.
# [2025-06-03 17:23:36.771650]   [14/1700] Fetching Steam info for App ID 1305500...
# [2025-06-03 17:23:37.339265]     ✓ Added game 'Captain Disaster in: The Dark Side of the Moon'.
# [2025-06-03 17:23:38.841583]   [15/1700] Fetching Steam info for App ID 2449260...
# [2025-06-03 17:23:39.029471]     ✗ Skipped App ID 2449260 (type=dlc).
# [2025-06-03 17:23:40.541370]   [16/1700] Fetching Steam info for App ID 1614850...
# [2025-06-03 17:23:40.726568]     ✓ Added game 'Colosseum VR'.
# [2025-06-03 17:23:42.236238]   [17/1700] Fetching Steam info for App ID 2053022...
# [2025-06-03 17:23:42.397981]     ✗ Skipped App ID 2053022 (type=dlc).
# [2025-06-03 17:23:43.902802]   [18/1700] Fetching Steam info for App ID 1539630...
# [2025-06-03 17:23:44.081178]     ✗ Skipped App ID 1539630 (type=demo).
# [2025-06-03 17:23:45.585736]   [19/1700] Fetching Steam info for App ID 2191550...
# [2025-06-03 17:23:45.818802]     ✓ Added game 'Pleh!'.
# [2025-06-03 17:23:47.319693]   [20/1700] Fetching Steam info for App ID 3088560...
# [2025-06-03 17:23:47.553571]     ✓ Added game 'Sunrise Down'.
# [2025-06-03 17:23:49.055051]   [21/1700] Fetching Steam info for App ID 2083550...
# [2025-06-03 17:23:49.267224]     ✗ Skipped App ID 2083550 (type=dlc).
# [2025-06-03 17:23:50.767640]   [22/1700] Fetching Steam info for App ID 2509090...
# [2025-06-03 17:23:51.078439]     ✗ No valid data for App ID 2509090.
# [2025-06-03 17:23:52.584773]   [23/1700] Fetching Steam info for App ID 1224784...
# [2025-06-03 17:23:52.810950]     ✗ Skipped App ID 1224784 (type=dlc).
# [2025-06-03 17:23:54.312810]   [24/1700] Fetching Steam info for App ID 1557470...
# [2025-06-03 17:23:54.505445]     ✓ Added game 'Baby Dragon Rancher'.
# [2025-06-03 17:23:56.009873]   [25/1700] Fetching Steam info for App ID 2251910...
# [2025-06-03 17:23:56.281685]     ✓ Added game 'Third'.
# [2025-06-03 17:23:57.790210]   [26/1700] Fetching Steam info for App ID 1571300...
# [2025-06-03 17:23:57.986082]     ✗ No valid data for App ID 1571300.
# [2025-06-03 17:23:59.495271]   [27/1700] Fetching Steam info for App ID 3161280...
# [2025-06-03 17:23:59.710368]     ✓ Added game 'Cozy Garden'.
# [2025-06-03 17:24:01.212244]   [28/1700] Fetching Steam info for App ID 2007480...
# [2025-06-03 17:24:01.404851]     ✓ Added game 'Airdrift'.
# [2025-06-03 17:24:02.919195]   [29/1700] Fetching Steam info for App ID 682080...
# [2025-06-03 17:24:03.080941]     ✓ Added game 'Pato Box'.
# [2025-06-03 17:24:04.592659]   [30/1700] Fetching Steam info for App ID 2421790...
# [2025-06-03 17:24:04.808710]     ✗ No valid data for App ID 2421790.
# [2025-06-03 17:24:06.309811]   [31/1700] Fetching Steam info for App ID 2168630...
# [2025-06-03 17:24:06.483665]     ✓ Added game 'L30-P4RD'.
# [2025-06-03 17:24:07.994608]   [32/1700] Fetching Steam info for App ID 2178100...
# [2025-06-03 17:24:08.279147]     ✓ Added game 'Two Beasts Or Not To Beast!'.
# [2025-06-03 17:24:09.779832]   [33/1700] Fetching Steam info for App ID 1522710...
# [2025-06-03 17:24:09.990338]     ✓ Added game 'LX Patterns'.
# [2025-06-03 17:24:11.494357]   [34/1700] Fetching Steam info for App ID 2963690...
# [2025-06-03 17:24:11.700763]     ✗ Skipped App ID 2963690 (type=dlc).
# [2025-06-03 17:24:13.204394]   [35/1700] Fetching Steam info for App ID 1860810...
# [2025-06-03 17:24:13.479001]     ✗ Skipped App ID 1860810 (type=dlc).
# [2025-06-03 17:24:14.985302]   [36/1700] Fetching Steam info for App ID 1267800...
# [2025-06-03 17:24:15.201945]     ✗ Skipped App ID 1267800 (type=dlc).
# [2025-06-03 17:24:16.703011]   [37/1700] Fetching Steam info for App ID 3631060...
# [2025-06-03 17:24:16.951047]     ✗ Skipped App ID 3631060 (type=demo).
# [2025-06-03 17:24:18.455653]   [38/1700] Fetching Steam info for App ID 2811640...
# [2025-06-03 17:24:18.671812]     ✗ Skipped App ID 2811640 (type=dlc).
# [2025-06-03 17:24:20.173154]   [39/1700] Fetching Steam info for App ID 2134540...
# [2025-06-03 17:24:20.385725]     ✓ Added game '战争冒险 序章'.
# [2025-06-03 17:24:21.888590]   [40/1700] Fetching Steam info for App ID 1653520...
# [2025-06-03 17:24:22.079533]     ✓ Added game 'Project Delta'.
# [2025-06-03 17:24:23.586097]   [41/1700] Fetching Steam info for App ID 2747030...
# [2025-06-03 17:24:23.765427]     ✗ No valid data for App ID 2747030.
# [2025-06-03 17:24:25.269944]   [42/1700] Fetching Steam info for App ID 3333800...
# [2025-06-03 17:24:25.494512]     ✗ Skipped App ID 3333800 (type=music).
# [2025-06-03 17:24:26.995788]   [43/1700] Fetching Steam info for App ID 903246...
# [2025-06-03 17:24:27.223910]     ✗ Skipped App ID 903246 (type=dlc).
# [2025-06-03 17:24:28.726568]   [44/1700] Fetching Steam info for App ID 1007230...
# [2025-06-03 17:24:28.907467]     ✓ Added game 'VRLab Academy Anatomy VR'.
# [2025-06-03 17:24:30.422690]   [45/1700] Fetching Steam info for App ID 1243570...
# [2025-06-03 17:24:30.634010]     ✗ Skipped App ID 1243570 (type=music).
# [2025-06-03 17:24:32.144525]   [46/1700] Fetching Steam info for App ID 3613980...
# [2025-06-03 17:24:32.336034]     ✓ Added game 'Sex Goddess Chronicles: Lilith's Seduction, An NSFW Porn VN'.
# [2025-06-03 17:24:33.846197]   [47/1700] Fetching Steam info for App ID 1219130...
# [2025-06-03 17:24:34.091773]     ✗ Skipped App ID 1219130 (type=music).
# [2025-06-03 17:24:35.606374]   [48/1700] Fetching Steam info for App ID 369829...
# [2025-06-03 17:24:35.954689]     ✗ Skipped App ID 369829 (type=dlc).
# [2025-06-03 17:24:37.461953]   [49/1700] Fetching Steam info for App ID 80891...
# [2025-06-03 17:24:37.691976]     ✗ No valid data for App ID 80891.
# [2025-06-03 17:24:39.193425]   [50/1700] Fetching Steam info for App ID 2653820...
# [2025-06-03 17:24:39.436788]     ✓ Added game 'DemonCountdown Playtest'.
# [2025-06-03 17:24:40.940660]   [51/1700] Fetching Steam info for App ID 3097510...
# [2025-06-03 17:24:41.164810]     ✓ Added game 'Bounty Brawl: Most Wanted'.
# [2025-06-03 17:24:42.665797]   [52/1700] Fetching Steam info for App ID 1458480...
# [2025-06-03 17:24:42.938427]     ✓ Added game 'Travellers'.
# [2025-06-03 17:24:44.446463]   [53/1700] Fetching Steam info for App ID 3500080...
# [2025-06-03 17:24:44.634022]     ✓ Added game 'Find My Love'.
# [2025-06-03 17:24:46.141717]   [54/1700] Fetching Steam info for App ID 1838369...
# [2025-06-03 17:24:46.303122]     ✗ No valid data for App ID 1838369.
# [2025-06-03 17:24:47.817387]   [55/1700] Fetching Steam info for App ID 3352640...
# [2025-06-03 17:24:47.987268]     ✗ No valid data for App ID 3352640.
# [2025-06-03 17:24:49.490406]   [56/1700] Fetching Steam info for App ID 1618380...
# [2025-06-03 17:24:49.672725]     ✓ Added game 'Spellmasons'.
# [2025-06-03 17:24:51.184809]   [57/1700] Fetching Steam info for App ID 3430230...
# [2025-06-03 17:24:51.364639]     ✗ Skipped App ID 3430230 (type=dlc).
# [2025-06-03 17:24:52.866387]   [58/1700] Fetching Steam info for App ID 3474980...
# [2025-06-03 17:24:53.197964]     ✓ Added game 'Blobbert 64'.
# [2025-06-03 17:24:54.699303]   [59/1700] Fetching Steam info for App ID 1745471...
# [2025-06-03 17:24:54.968955]     ✗ Skipped App ID 1745471 (type=dlc).
# [2025-06-03 17:24:56.474902]   [60/1700] Fetching Steam info for App ID 3579470...
# [2025-06-03 17:24:56.682587]     ✗ Skipped App ID 3579470 (type=demo).
# [2025-06-03 17:24:58.183494]   [61/1700] Fetching Steam info for App ID 2372090...
# [2025-06-03 17:24:58.414729]     ✓ Added game 'RollerBall'.
# [2025-06-03 17:24:59.916693]   [62/1700] Fetching Steam info for App ID 2022280...
# [2025-06-03 17:25:00.108029]     ✗ No valid data for App ID 2022280.
# [2025-06-03 17:25:01.617789]   [63/1700] Fetching Steam info for App ID 294310...
# [2025-06-03 17:25:01.827535]     ✗ Skipped App ID 294310 (type=dlc).
# [2025-06-03 17:25:03.329408]   [64/1700] Fetching Steam info for App ID 2940620...
# [2025-06-03 17:25:03.560483]     ✓ Added game 'Cards of Eternity: The Wheel of Time'.
# [2025-06-03 17:25:05.061592]   [65/1700] Fetching Steam info for App ID 2880270...
# [2025-06-03 17:25:05.256808]     ✓ Added game 'Capyverse Odyssey'.
# [2025-06-03 17:25:06.758464]   [66/1700] Fetching Steam info for App ID 1407620...
# [2025-06-03 17:25:06.974547]     ✓ Added game 'Last Hope on Earth'.
# [2025-06-03 17:25:08.478634]   [67/1700] Fetching Steam info for App ID 2385720...
# [2025-06-03 17:25:08.671173]     ✓ Added game 'The Police Mystery'.
# [2025-06-03 17:25:10.185313]   [68/1700] Fetching Steam info for App ID 1914860...
# [2025-06-03 17:25:10.363079]     ✗ Skipped App ID 1914860 (type=demo).
# [2025-06-03 17:25:11.863560]   [69/1700] Fetching Steam info for App ID 1046230...
# [2025-06-03 17:25:12.096469]     ✓ Added game 'Soccer Player Simulator'.
# [2025-06-03 17:25:13.599017]   [70/1700] Fetching Steam info for App ID 540010...
# [2025-06-03 17:25:13.797473]     ✓ Added game 'Symphony of the Machine'.
# [2025-06-03 17:25:15.301924]   [71/1700] Fetching Steam info for App ID 545810...
# [2025-06-03 17:25:15.497820]     ✗ Skipped App ID 545810 (type=demo).
# [2025-06-03 17:25:17.001799]   [72/1700] Fetching Steam info for App ID 2077820...
# [2025-06-03 17:25:17.654000]     ✗ Skipped App ID 2077820 (type=dlc).
# [2025-06-03 17:25:19.167558]   [73/1700] Fetching Steam info for App ID 844350...
# [2025-06-03 17:25:19.449805]     ✓ Added game 'Obscurity'.
# [2025-06-03 17:25:20.956209]   [74/1700] Fetching Steam info for App ID 1133330...
# [2025-06-03 17:25:21.166405]     ✓ Added game 'Helicopter Simulator'.
# [2025-06-03 17:25:22.667832]   [75/1700] Fetching Steam info for App ID 1838830...
# [2025-06-03 17:25:22.856320]     ✓ Added game 'Paradox Factor'.
# [2025-06-03 17:25:24.358163]   [76/1700] Fetching Steam info for App ID 2097900...
# [2025-06-03 17:25:24.569924]     ✓ Added game 'Hold or Die'.
# [2025-06-03 17:25:26.078955]   [77/1700] Fetching Steam info for App ID 790831...
# [2025-06-03 17:25:26.287385]     ✗ Skipped App ID 790831 (type=dlc).
# [2025-06-03 17:25:27.791934]   [78/1700] Fetching Steam info for App ID 361470...
# [2025-06-03 17:25:27.995480]     ✗ Skipped App ID 361470 (type=dlc).
# [2025-06-03 17:25:29.501987]   [79/1700] Fetching Steam info for App ID 2414260...
# [2025-06-03 17:25:29.693151]     ✓ Added game 'Athena's Revenge'.
# [2025-06-03 17:25:31.209040]   [80/1700] Fetching Steam info for App ID 916170...
# [2025-06-03 17:25:31.490514]     ✗ Skipped App ID 916170 (type=dlc).
# [2025-06-03 17:25:32.991586]   [81/1700] Fetching Steam info for App ID 436340...
# [2025-06-03 17:25:33.341255]     ✓ Added game 'Kiya'.
# [2025-06-03 17:25:34.853795]   [82/1700] Fetching Steam info for App ID 3131080...
# [2025-06-03 17:25:35.067939]     ✗ Skipped App ID 3131080 (type=dlc).
# [2025-06-03 17:25:36.572358]   [83/1700] Fetching Steam info for App ID 2702250...
# [2025-06-03 17:25:36.833471]     ✓ Added game 'Psyko'.
# [2025-06-03 17:25:38.345594]   [84/1700] Fetching Steam info for App ID 1176243...
# [2025-06-03 17:25:38.536772]     ✗ Skipped App ID 1176243 (type=dlc).
# [2025-06-03 17:25:40.042470]   [85/1700] Fetching Steam info for App ID 680870...
# [2025-06-03 17:25:40.234352]     ✗ No valid data for App ID 680870.
# [2025-06-03 17:25:41.742513]   [86/1700] Fetching Steam info for App ID 3583570...
# [2025-06-03 17:25:41.945457]     ✓ Added game 'The Legend of Bubble Boy'.
# [2025-06-03 17:25:43.447683]   [87/1700] Fetching Steam info for App ID 1782950...
# [2025-06-03 17:25:43.658625]     ✓ Added game 'SpaceDominator'.
# [2025-06-03 17:25:45.159100]   [88/1700] Fetching Steam info for App ID 1445790...
# [2025-06-03 17:25:45.346495]     ✓ Added game 'Make Way'.
# [2025-06-03 17:25:46.847666]   [89/1700] Fetching Steam info for App ID 1206020...
# [2025-06-03 17:25:47.041737]     ✓ Added game 'Justice Strikes'.
# [2025-06-03 17:25:48.542487]   [90/1700] Fetching Steam info for App ID 3278460...
# [2025-06-03 17:25:48.732630]     ✓ Added game 'Catch A Fish'.
# [2025-06-03 17:25:50.237344]   [91/1700] Fetching Steam info for App ID 337430...
# [2025-06-03 17:25:50.482000]     ✗ Skipped App ID 337430 (type=demo).
# [2025-06-03 17:25:51.984873]   [92/1700] Fetching Steam info for App ID 3742650...
# [2025-06-03 17:25:52.197523]     ✓ Added game '世界之外的愚人船'.
# [2025-06-03 17:25:53.697748]   [93/1700] Fetching Steam info for App ID 3608730...
# [2025-06-03 17:25:53.907557]     ✓ Added game 'Tales for the Long Nights'.
# [2025-06-03 17:25:55.410723]   [94/1700] Fetching Steam info for App ID 1355360...
# [2025-06-03 17:25:55.740458]     ✓ Added game 'Trouble Hunter Chronicles: The Stolen Creed'.
# [2025-06-03 17:25:57.247945]   [95/1700] Fetching Steam info for App ID 3715630...
# [2025-06-03 17:25:57.501134]     ✓ Added game 'Adohiinage'.
# [2025-06-03 17:25:59.008252]   [96/1700] Fetching Steam info for App ID 1663080...
# [2025-06-03 17:25:59.186765]     ✗ Skipped App ID 1663080 (type=dlc).
# [2025-06-03 17:26:00.701044]   [97/1700] Fetching Steam info for App ID 2231580...
# [2025-06-03 17:26:00.884359]     ✓ Added game 'We Are the Universe'.
# [2025-06-03 17:26:02.395678]   [98/1700] Fetching Steam info for App ID 2230060...
# [2025-06-03 17:26:02.605219]     ✓ Added game 'Night&Scape'.
# [2025-06-03 17:26:04.112460]   [99/1700] Fetching Steam info for App ID 2102380...
# [2025-06-03 17:26:04.437426]     ✗ Skipped App ID 2102380 (type=dlc).
# [2025-06-03 17:26:05.944009]   [100/1700] Fetching Steam info for App ID 2819800...
# [2025-06-03 17:26:06.128838]     ✗ Skipped App ID 2819800 (type=demo).
# [2025-06-03 17:26:07.637706]   [101/1700] Fetching Steam info for App ID 2671310...
# [2025-06-03 17:26:07.833237]     ✓ Added game 'Block-ed'.
# [2025-06-03 17:26:09.337662]   [102/1700] Fetching Steam info for App ID 2681920...
# [2025-06-03 17:26:09.525447]     ✓ Added game '末世孤镇 Doomsday Lonely town'.
# [2025-06-03 17:26:11.032779]   [103/1700] Fetching Steam info for App ID 1380960...
# [2025-06-03 17:26:11.227756]     ✓ Added game 'The Outpost'.
# [2025-06-03 17:26:12.728612]   [104/1700] Fetching Steam info for App ID 1785100...
# [2025-06-03 17:26:12.951688]     ✓ Added game 'Stop the Saturnians!'.
# [2025-06-03 17:26:14.454451]   [105/1700] Fetching Steam info for App ID 2185510...
# [2025-06-03 17:26:14.743035]     ✓ Added game 'TOUCHSTARVED'.
# [2025-06-03 17:26:16.257182]   [106/1700] Fetching Steam info for App ID 3551630...
# [2025-06-03 17:26:16.632628]     ✓ Added game 'Backrooms: The Next Level'.
# [2025-06-03 17:26:18.139423]   [107/1700] Fetching Steam info for App ID 2559630...
# [2025-06-03 17:26:18.362663]     ✓ Added game 'Hentai Maze'.
# [2025-06-03 17:26:19.865504]   [108/1700] Fetching Steam info for App ID 1856580...
# [2025-06-03 17:26:20.109375]     ✗ Skipped App ID 1856580 (type=music).
# [2025-06-03 17:26:21.610039]   [109/1700] Fetching Steam info for App ID 1726660...
# [2025-06-03 17:26:21.923961]     ✓ Added game 'stopDrop.'.
# [2025-06-03 17:26:23.428749]   [110/1700] Fetching Steam info for App ID 2056030...
# [2025-06-03 17:26:23.702503]     ✓ Added game 'Rainbow Runner'.
# [2025-06-03 17:26:25.209390]   [111/1700] Fetching Steam info for App ID 926970...
# [2025-06-03 17:26:25.431982]     ✗ Skipped App ID 926970 (type=dlc).
# [2025-06-03 17:26:26.933729]   [112/1700] Fetching Steam info for App ID 1281990...
# [2025-06-03 17:26:27.133254]     ✓ Added game 'CoronaFighter'.
# [2025-06-03 17:26:28.637409]   [113/1700] Fetching Steam info for App ID 3538130...
# [2025-06-03 17:26:28.801559]     ✓ Added game 'After Juice: Animal Disco Mafia'.
# [2025-06-03 17:26:30.316314]   [114/1700] Fetching Steam info for App ID 904700...
# [2025-06-03 17:26:30.529574]     ✓ Added game 'Down Ward'.
# [2025-06-03 17:26:32.030175]   [115/1700] Fetching Steam info for App ID 1560191...
# [2025-06-03 17:26:32.225922]     ✗ Skipped App ID 1560191 (type=dlc).
# [2025-06-03 17:26:33.738068]   [116/1700] Fetching Steam info for App ID 3143720...
# [2025-06-03 17:26:33.910862]     ✓ Added game '超兽启动 Playtest'.
# [2025-06-03 17:26:35.414871]   [117/1700] Fetching Steam info for App ID 2253840...
# [2025-06-03 17:26:35.638196]     ✗ Skipped App ID 2253840 (type=music).
# [2025-06-03 17:26:37.139413]   [118/1700] Fetching Steam info for App ID 1846960...
# [2025-06-03 17:26:37.316596]     ✓ Added game 'Where's My Horse? An Escape the Room Adventure'.
# [2025-06-03 17:26:38.819477]   [119/1700] Fetching Steam info for App ID 356650...
# [2025-06-03 17:26:39.026769]     ✓ Added game 'Death's Gambit: Afterlife'.
# [2025-06-03 17:26:40.527668]   [120/1700] Fetching Steam info for App ID 2362100...
# [2025-06-03 17:26:40.737167]     ✗ Skipped App ID 2362100 (type=demo).
# [2025-06-03 17:26:42.239087]   [121/1700] Fetching Steam info for App ID 346860...
# [2025-06-03 17:26:42.401330]     ✗ No valid data for App ID 346860.
# [2025-06-03 17:26:43.908274]   [122/1700] Fetching Steam info for App ID 3310830...
# [2025-06-03 17:26:44.095324]     ✓ Added game 'Linked'.
# [2025-06-03 17:26:45.599044]   [123/1700] Fetching Steam info for App ID 2073210...
# [2025-06-03 17:26:45.810983]     ✗ Skipped App ID 2073210 (type=dlc).
# [2025-06-03 17:26:47.312669]   [124/1700] Fetching Steam info for App ID 670090...
# [2025-06-03 17:26:47.511914]     ✓ Added game 'FallenCore'.
# [2025-06-03 17:26:49.016402]   [125/1700] Fetching Steam info for App ID 771040...
# [2025-06-03 17:26:49.187810]     ✗ No valid data for App ID 771040.
# [2025-06-03 17:26:50.690604]   [126/1700] Fetching Steam info for App ID 735620...
# [2025-06-03 17:26:50.838382]     ✗ No valid data for App ID 735620.
# [2025-06-03 17:26:52.349415]   [127/1700] Fetching Steam info for App ID 2260800...
# [2025-06-03 17:26:52.716660]     ✓ Added game 'nothing_matters'.
# [2025-06-03 17:26:54.218699]   [128/1700] Fetching Steam info for App ID 527280...
# [2025-06-03 17:26:54.459215]     ✓ Added game 'Nights of Azure'.
# [2025-06-03 17:26:55.966999]   [129/1700] Fetching Steam info for App ID 548700...
# [2025-06-03 17:26:56.176542]     ✗ Skipped App ID 548700 (type=dlc).
# [2025-06-03 17:26:57.679177]   [130/1700] Fetching Steam info for App ID 2490820...
# [2025-06-03 17:26:57.867613]     ✓ Added game 'Ovine Replica'.
# [2025-06-03 17:26:59.372118]   [131/1700] Fetching Steam info for App ID 1926550...
# [2025-06-03 17:26:59.576305]     ✓ Added game 'Orbit Or Beat Extended Edition'.
# [2025-06-03 17:27:01.077345]   [132/1700] Fetching Steam info for App ID 419240...
# [2025-06-03 17:27:01.263978]     ✗ Skipped App ID 419240 (type=video).
# [2025-06-03 17:27:02.772973]   [133/1700] Fetching Steam info for App ID 318480...
# [2025-06-03 17:27:02.988464]     ✓ Added game 'Burnstar'.
# [2025-06-03 17:27:04.488941]   [134/1700] Fetching Steam info for App ID 1700540...
# [2025-06-03 17:27:04.930935]     ✗ Skipped App ID 1700540 (type=dlc).
# [2025-06-03 17:27:06.437343]   [135/1700] Fetching Steam info for App ID 771880...
# [2025-06-03 17:27:06.615025]     ✗ Skipped App ID 771880 (type=demo).
# [2025-06-03 17:27:08.127719]   [136/1700] Fetching Steam info for App ID 2351630...
# [2025-06-03 17:27:08.307189]     ✓ Added game 'Kingdom Unwritten'.
# [2025-06-03 17:27:09.811039]   [137/1700] Fetching Steam info for App ID 3138520...
# [2025-06-03 17:27:09.984708]     ✓ Added game 'To Clean The Mountain'.
# [2025-06-03 17:27:11.496803]   [138/1700] Fetching Steam info for App ID 2989910...
# [2025-06-03 17:27:11.713118]     ✗ Skipped App ID 2989910 (type=demo).
# [2025-06-03 17:27:13.217793]   [139/1700] Fetching Steam info for App ID 720530...
# [2025-06-03 17:27:13.390980]     ✗ Skipped App ID 720530 (type=music).
# [2025-06-03 17:27:14.898842]   [140/1700] Fetching Steam info for App ID 2665850...
# [2025-06-03 17:27:15.183202]     ✗ Skipped App ID 2665850 (type=dlc).
# [2025-06-03 17:27:16.684320]   [141/1700] Fetching Steam info for App ID 2168000...
# [2025-06-03 17:27:16.897441]     ✓ Added game 'Trader of the Night'.
# [2025-06-03 17:27:18.399450]   [142/1700] Fetching Steam info for App ID 1241740...
# [2025-06-03 17:27:18.568687]     ✓ Added game 'ENDURE'.
# [2025-06-03 17:27:20.076554]   [143/1700] Fetching Steam info for App ID 369950...
# [2025-06-03 17:27:20.314423]     ✗ Skipped App ID 369950 (type=dlc).
# [2025-06-03 17:27:21.815730]   [144/1700] Fetching Steam info for App ID 861990...
# [2025-06-03 17:27:22.006934]     ✗ Skipped App ID 861990 (type=demo).
# [2025-06-03 17:27:23.511035]   [145/1700] Fetching Steam info for App ID 1482530...
# [2025-06-03 17:27:23.781004]     ✓ Added game 'GeometryBricks'.
# [2025-06-03 17:27:25.291389]   [146/1700] Fetching Steam info for App ID 1764630...
# [2025-06-03 17:27:25.460560]     ✗ Skipped App ID 1764630 (type=dlc).
# [2025-06-03 17:27:26.970436]   [147/1700] Fetching Steam info for App ID 426743...
# [2025-06-03 17:27:27.143755]     ✗ Skipped App ID 426743 (type=dlc).
# [2025-06-03 17:27:28.656048]   [148/1700] Fetching Steam info for App ID 2609200...
# [2025-06-03 17:27:28.834086]     ✓ Added game 'Escape!'.
# [2025-06-03 17:27:30.350044]   [149/1700] Fetching Steam info for App ID 2708800...
# [2025-06-03 17:27:30.559673]     ✓ Added game 'Monster Parade: Nurturing a Hero’s Sacred Sword!?'.
# [2025-06-03 17:27:32.060762]   [150/1700] Fetching Steam info for App ID 568060...
# [2025-06-03 17:27:32.302091]     ✓ Added game 'Hyper Void'.
# [2025-06-03 17:27:33.804587]   [151/1700] Fetching Steam info for App ID 2405790...
# [2025-06-03 17:27:34.522865]     ✗ Skipped App ID 2405790 (type=dlc).
# [2025-06-03 17:27:36.030234]   [152/1700] Fetching Steam info for App ID 1998130...
# [2025-06-03 17:27:36.251445]     ✓ Added game 'TOTEMS'.
# [2025-06-03 17:27:37.756160]   [153/1700] Fetching Steam info for App ID 564280...
# [2025-06-03 17:27:37.937207]     ✓ Added game 'Adventuring Gentleman'.
# [2025-06-03 17:27:39.447345]   [154/1700] Fetching Steam info for App ID 206570...
# [2025-06-03 17:27:39.594815]     ✗ No valid data for App ID 206570.
# [2025-06-03 17:27:41.107244]   [155/1700] Fetching Steam info for App ID 1095750...
# [2025-06-03 17:27:41.296127]     ✓ Added game 'Faith of Fate'.
# [2025-06-03 17:27:42.808503]   [156/1700] Fetching Steam info for App ID 3414480...
# [2025-06-03 17:27:43.003044]     ✓ Added game 'Double Trip'.
# [2025-06-03 17:27:44.506261]   [157/1700] Fetching Steam info for App ID 1842976...
# [2025-06-03 17:27:44.796007]     ✗ Skipped App ID 1842976 (type=dlc).
# [2025-06-03 17:27:46.299293]   [158/1700] Fetching Steam info for App ID 2766790...
# [2025-06-03 17:27:46.486805]     ✓ Added game '飞跃星球（Eggy Space）'.
# [2025-06-03 17:27:47.988031]   [159/1700] Fetching Steam info for App ID 293098...
# [2025-06-03 17:27:48.171548]     ✗ Skipped App ID 293098 (type=dlc).
# [2025-06-03 17:27:49.679534]   [160/1700] Fetching Steam info for App ID 620743...
# [2025-06-03 17:27:49.857316]     ✗ Skipped App ID 620743 (type=dlc).
# [2025-06-03 17:27:51.363226]   [161/1700] Fetching Steam info for App ID 1244370...
# [2025-06-03 17:27:51.556174]     ✓ Added game 'Electronic Squash'.
# [2025-06-03 17:27:53.065885]   [162/1700] Fetching Steam info for App ID 702415...
# [2025-06-03 17:27:53.243391]     ✗ Skipped App ID 702415 (type=dlc).
# [2025-06-03 17:27:54.754225]   [163/1700] Fetching Steam info for App ID 3032700...
# [2025-06-03 17:27:54.942683]     ✗ Skipped App ID 3032700 (type=demo).
# [2025-06-03 17:27:56.444468]   [164/1700] Fetching Steam info for App ID 3417350...
# [2025-06-03 17:27:56.695885]     ✓ Added game 'Hero Hellspawn - Learn Arithmetic'.
# [2025-06-03 17:27:58.202032]   [165/1700] Fetching Steam info for App ID 1073160...
# [2025-06-03 17:27:58.371571]     ✗ Skipped App ID 1073160 (type=dlc).
# [2025-06-03 17:27:59.886018]   [166/1700] Fetching Steam info for App ID 960700...
# [2025-06-03 17:28:00.076550]     ✓ Added game 'GUNS 'n GUTS'.
# [2025-06-03 17:28:01.590360]   [167/1700] Fetching Steam info for App ID 1531850...
# [2025-06-03 17:28:01.766661]     ✗ Skipped App ID 1531850 (type=demo).
# [2025-06-03 17:28:03.270360]   [168/1700] Fetching Steam info for App ID 2367450...
# [2025-06-03 17:28:03.459457]     ✗ Skipped App ID 2367450 (type=demo).
# [2025-06-03 17:28:04.966213]   [169/1700] Fetching Steam info for App ID 625970...
# [2025-06-03 17:28:05.144794]     ✗ Skipped App ID 625970 (type=video).
# [2025-06-03 17:28:06.660136]   [170/1700] Fetching Steam info for App ID 2934650...
# [2025-06-03 17:28:06.893775]     ✓ Added game 'Ocean Mirror Playtest'.
# [2025-06-03 17:28:08.394344]   [171/1700] Fetching Steam info for App ID 1131060...
# [2025-06-03 17:28:08.582671]     ✓ Added game 'Dungeon of Eyden'.
# [2025-06-03 17:28:10.092324]   [172/1700] Fetching Steam info for App ID 297990...
# [2025-06-03 17:28:10.309312]     ✗ Skipped App ID 297990 (type=dlc).
# [2025-06-03 17:28:11.810260]   [173/1700] Fetching Steam info for App ID 2395940...
# [2025-06-03 17:28:12.027689]     ✓ Added game 'ArchiHexago'.
# [2025-06-03 17:28:13.529222]   [174/1700] Fetching Steam info for App ID 3545590...
# [2025-06-03 17:28:13.713345]     ✓ Added game 'Salary-Mon | Hiro Versus His Demons'.
# [2025-06-03 17:28:15.219039]   [175/1700] Fetching Steam info for App ID 1994750...
# [2025-06-03 17:28:15.848258]     ✓ Added game 'Workplace Malice'.
# [2025-06-03 17:28:17.354111]   [176/1700] Fetching Steam info for App ID 3497930...
# [2025-06-03 17:28:17.606787]     ✓ Added game 'Gamba Gun'.
# [2025-06-03 17:28:19.110288]   [177/1700] Fetching Steam info for App ID 2697540...
# [2025-06-03 17:28:19.335000]     ✓ Added game 'FastPack'.
# [2025-06-03 17:28:20.835503]   [178/1700] Fetching Steam info for App ID 2515180...
# [2025-06-03 17:28:21.073475]     ✓ Added game '調教カテイ～性開発された肢体は元カレを忘れられない～'.
# [2025-06-03 17:28:22.577803]   [179/1700] Fetching Steam info for App ID 1972160...
# [2025-06-03 17:28:22.813440]     ✓ Added game 'Virtual Hunting Experience'.
# [2025-06-03 17:28:24.314627]   [180/1700] Fetching Steam info for App ID 3089680...
# [2025-06-03 17:28:24.556045]     ✓ Added game 'Fishing Mayhem'.
# [2025-06-03 17:28:26.057360]   [181/1700] Fetching Steam info for App ID 2339830...
# [2025-06-03 17:28:26.278077]     ✗ Skipped App ID 2339830 (type=dlc).
# [2025-06-03 17:28:27.783232]   [182/1700] Fetching Steam info for App ID 454100...
# [2025-06-03 17:28:27.977206]     ✓ Added game 'Dungeon Escape'.
# [2025-06-03 17:28:29.489589]   [183/1700] Fetching Steam info for App ID 3396240...
# [2025-06-03 17:28:29.667461]     ✓ Added game 'Grove Fisher Playtest'.
# [2025-06-03 17:28:31.170618]   [184/1700] Fetching Steam info for App ID 2776140...
# [2025-06-03 17:28:31.390458]     ✗ No valid data for App ID 2776140.
# [2025-06-03 17:28:32.891385]   [185/1700] Fetching Steam info for App ID 2097310...
# [2025-06-03 17:28:33.099973]     ✗ Skipped App ID 2097310 (type=dlc).
# [2025-06-03 17:28:34.601895]   [186/1700] Fetching Steam info for App ID 2749670...
# [2025-06-03 17:28:34.825106]     ✓ Added game 'Psychological Hacker Playtest'.
# [2025-06-03 17:28:36.330514]   [187/1700] Fetching Steam info for App ID 888420...
# [2025-06-03 17:28:36.533812]     ✓ Added game 'Abunka'.
# [2025-06-03 17:28:38.035773]   [188/1700] Fetching Steam info for App ID 265191...
# [2025-06-03 17:28:38.231676]     ✗ Skipped App ID 265191 (type=dlc).
# [2025-06-03 17:28:39.744630]   [189/1700] Fetching Steam info for App ID 2771590...
# [2025-06-03 17:28:39.912938]     ✓ Added game 'Chick'n Mushroom Soup'.
# [2025-06-03 17:28:41.423548]   [190/1700] Fetching Steam info for App ID 579940...
# [2025-06-03 17:28:41.657847]     ✓ Added game 'Race for the Galaxy'.
# [2025-06-03 17:28:43.158542]   [191/1700] Fetching Steam info for App ID 3196780...
# [2025-06-03 17:28:43.368390]     ✓ Added game 'Skylax! The Lab Runner'.
# [2025-06-03 17:28:44.869007]   [192/1700] Fetching Steam info for App ID 326650...
# [2025-06-03 17:28:45.042982]     ✓ Added game 'The Legend of Candlewind: Nights & Candles'.
# [2025-06-03 17:28:46.556991]   [193/1700] Fetching Steam info for App ID 2608480...
# [2025-06-03 17:28:46.871050]     ✗ Skipped App ID 2608480 (type=dlc).
# [2025-06-03 17:28:48.372834]   [194/1700] Fetching Steam info for App ID 2748020...
# [2025-06-03 17:28:48.632977]     ✓ Added game 'Adventure Trip: Amazing World 3 Collector's Edition'.
# [2025-06-03 17:28:50.137987]   [195/1700] Fetching Steam info for App ID 2377550...
# [2025-06-03 17:28:50.362266]     ✗ Skipped App ID 2377550 (type=music).
# [2025-06-03 17:28:51.863015]   [196/1700] Fetching Steam info for App ID 1648412...
# [2025-06-03 17:28:52.062579]     ✗ Skipped App ID 1648412 (type=dlc).
# [2025-06-03 17:28:53.573634]   [197/1700] Fetching Steam info for App ID 1180030...
# [2025-06-03 17:28:53.783148]     ✓ Added game 'Wardwell House'.
# [2025-06-03 17:28:55.284522]   [198/1700] Fetching Steam info for App ID 1862830...
# [2025-06-03 17:28:55.470609]     ✓ Added game 'Lost Artifacts Mysterious Book Collector's Edition'.
# [2025-06-03 17:28:56.986990]   [199/1700] Fetching Steam info for App ID 3143510...
# [2025-06-03 17:28:57.185093]     ✓ Added game 'Pixel Frenzy'.
# [2025-06-03 17:28:58.687660]   [200/1700] Fetching Steam info for App ID 3577090...
# [2025-06-03 17:28:58.871899]     ✗ Skipped App ID 3577090 (type=dlc).
# [2025-06-03 17:29:00.379167]   [201/1700] Fetching Steam info for App ID 1807930...
# [2025-06-03 17:29:00.648359]     ✓ Added game 'Railway Islands - Puzzle'.
# [2025-06-03 17:29:02.163000]   [202/1700] Fetching Steam info for App ID 490410...
# [2025-06-03 17:29:02.419343]     ✗ Skipped App ID 490410 (type=dlc).
# [2025-06-03 17:29:03.925210]   [203/1700] Fetching Steam info for App ID 506804...
# [2025-06-03 17:29:04.151372]     ✗ Skipped App ID 506804 (type=dlc).
# [2025-06-03 17:29:05.655011]   [204/1700] Fetching Steam info for App ID 3383090...
# [2025-06-03 17:29:05.832681]     ✓ Added game 'UFO Stole My Egg!'.
# [2025-06-03 17:29:07.339439]   [205/1700] Fetching Steam info for App ID 2073520...
# [2025-06-03 17:29:07.631321]     ✓ Added game 'Minimal Bubble Pop'.
# [2025-06-03 17:29:09.139399]   [206/1700] Fetching Steam info for App ID 1068190...
# [2025-06-03 17:29:09.366537]     ✓ Added game '重生轮回/Reborn Not Again'.
# [2025-06-03 17:29:10.867204]   [207/1700] Fetching Steam info for App ID 1314260...
# [2025-06-03 17:29:11.115272]     ✗ No valid data for App ID 1314260.
# [2025-06-03 17:29:12.620176]   [208/1700] Fetching Steam info for App ID 82090...
# [2025-06-03 17:29:12.784301]     ✗ No valid data for App ID 82090.
# [2025-06-03 17:29:14.285279]   [209/1700] Fetching Steam info for App ID 1732090...
# [2025-06-03 17:29:14.494672]     ✓ Added game 'Words Can Kill'.
# [2025-06-03 17:29:15.996085]   [210/1700] Fetching Steam info for App ID 3425840...
# [2025-06-03 17:29:16.235815]     ✗ Skipped App ID 3425840 (type=dlc).
# [2025-06-03 17:29:17.736840]   [211/1700] Fetching Steam info for App ID 2386310...
# [2025-06-03 17:29:17.934019]     ✓ Added game 'Ultros'.
# [2025-06-03 17:29:19.447387]   [212/1700] Fetching Steam info for App ID 2389770...
# [2025-06-03 17:29:19.707412]     ✓ Added game 'Arobynn: Below The Surface'.
# [2025-06-03 17:29:21.223630]   [213/1700] Fetching Steam info for App ID 2123860...
# [2025-06-03 17:29:21.481229]     ✗ Skipped App ID 2123860 (type=demo).
# [2025-06-03 17:29:22.982752]   [214/1700] Fetching Steam info for App ID 322000...
# [2025-06-03 17:29:23.242988]     ✗ Skipped App ID 322000 (type=dlc).
# [2025-06-03 17:29:24.743369]   [215/1700] Fetching Steam info for App ID 846570...
# [2025-06-03 17:29:24.929344]     ✗ Skipped App ID 846570 (type=video).
# [2025-06-03 17:29:26.430822]   [216/1700] Fetching Steam info for App ID 3733730...
# [2025-06-03 17:29:26.619014]     ✓ Added game 'Nomyou'.
# [2025-06-03 17:29:28.134349]   [217/1700] Fetching Steam info for App ID 2725060...
# [2025-06-03 17:29:28.379344]     ✗ Skipped App ID 2725060 (type=demo).
# [2025-06-03 17:29:29.895437]   [218/1700] Fetching Steam info for App ID 3149980...
# [2025-06-03 17:29:30.137402]     ✓ Added game 'Love n Life: Happy Student'.
# [2025-06-03 17:29:31.638820]   [219/1700] Fetching Steam info for App ID 827880...
# [2025-06-03 17:29:31.820534]     ✓ Added game 'The Endless Mission'.
# [2025-06-03 17:29:33.330690]   [220/1700] Fetching Steam info for App ID 2008690...
# [2025-06-03 17:29:33.573271]     ✗ Skipped App ID 2008690 (type=demo).
# [2025-06-03 17:29:35.075116]   [221/1700] Fetching Steam info for App ID 3742230...
# [2025-06-03 17:29:35.287570]     ✗ Skipped App ID 3742230 (type=dlc).
# [2025-06-03 17:29:36.791503]   [222/1700] Fetching Steam info for App ID 2807520...
# [2025-06-03 17:29:36.969890]     ✗ Skipped App ID 2807520 (type=demo).
# [2025-06-03 17:29:38.477285]   [223/1700] Fetching Steam info for App ID 2553690...
# [2025-06-03 17:29:38.702429]     ✓ Added game 'Canyon Rush'.
# [2025-06-03 17:29:40.203088]   [224/1700] Fetching Steam info for App ID 3081540...
# [2025-06-03 17:29:40.447602]     ✓ Added game 'Magman'.
# [2025-06-03 17:29:41.956414]   [225/1700] Fetching Steam info for App ID 1690430...
# [2025-06-03 17:29:42.193497]     ✓ Added game 'Relic Hunters Legend Closed Beta'.
# [2025-06-03 17:29:43.694582]   [226/1700] Fetching Steam info for App ID 1205861...
# [2025-06-03 17:29:44.293123]     ✗ Skipped App ID 1205861 (type=dlc).
# [2025-06-03 17:29:45.798432]   [227/1700] Fetching Steam info for App ID 369170...
# [2025-06-03 17:29:46.000141]     ✗ No valid data for App ID 369170.
# [2025-06-03 17:29:47.504257]   [228/1700] Fetching Steam info for App ID 23150...
# [2025-06-03 17:29:47.777672]     ✓ Added game 'Fluttabyes'.
# [2025-06-03 17:29:49.282545]   [229/1700] Fetching Steam info for App ID 1363210...
# [2025-06-03 17:29:49.532585]     ✓ Added game 'Live by the Sword: Tactics'.
# [2025-06-03 17:29:51.033878]   [230/1700] Fetching Steam info for App ID 3093590...
# [2025-06-03 17:29:51.283666]     ✓ Added game 'Kemopop!'.
# [2025-06-03 17:29:52.788267]   [231/1700] Fetching Steam info for App ID 1570270...
# [2025-06-03 17:29:52.999705]     ✗ Skipped App ID 1570270 (type=demo).
# [2025-06-03 17:29:54.501393]   [232/1700] Fetching Steam info for App ID 1627360...
# [2025-06-03 17:29:54.743106]     ✓ Added game 'Vulkan: Lost Planet'.
# [2025-06-03 17:29:56.244118]   [233/1700] Fetching Steam info for App ID 2736600...
# [2025-06-03 17:29:56.479906]     ✓ Added game 'Help Santa In Christmas Xmas Game'.
# [2025-06-03 17:29:57.980671]   [234/1700] Fetching Steam info for App ID 329821...
# [2025-06-03 17:29:58.199075]     ✗ Skipped App ID 329821 (type=dlc).
# [2025-06-03 17:29:59.700564]   [235/1700] Fetching Steam info for App ID 3002700...
# [2025-06-03 17:29:59.924629]     ✓ Added game 'Aria - Das Echo der vergessenen Zeit'.
# [2025-06-03 17:30:01.429628]   [236/1700] Fetching Steam info for App ID 3227880...
# [2025-06-03 17:30:01.638658]     ✗ Skipped App ID 3227880 (type=dlc).
# [2025-06-03 17:30:03.140473]   [237/1700] Fetching Steam info for App ID 3415260...
# [2025-06-03 17:30:03.354144]     ✓ Added game 'Divine Reckoning'.
# [2025-06-03 17:30:04.855591]   [238/1700] Fetching Steam info for App ID 3457670...
# [2025-06-03 17:30:05.077561]     ✓ Added game 'Killing Dead Playtest'.
# [2025-06-03 17:30:06.583992]   [239/1700] Fetching Steam info for App ID 1998772...
# [2025-06-03 17:30:06.768810]     ✗ Skipped App ID 1998772 (type=dlc).
# [2025-06-03 17:30:08.274712]   [240/1700] Fetching Steam info for App ID 222520...
# [2025-06-03 17:30:08.505091]     ✓ Added game 'Champions of Regnum'.
# [2025-06-03 17:30:10.006745]   [241/1700] Fetching Steam info for App ID 1001110...
# [2025-06-03 17:30:10.225881]     ✗ Skipped App ID 1001110 (type=music).
# [2025-06-03 17:30:11.727109]   [242/1700] Fetching Steam info for App ID 2808640...
# [2025-06-03 17:30:11.961050]     ✓ Added game 'Lazulight: By Your Side'.
# [2025-06-03 17:30:13.461454]   [243/1700] Fetching Steam info for App ID 1750910...
# [2025-06-03 17:30:13.657723]     ✓ Added game 'Dose Response'.
# [2025-06-03 17:30:15.171505]   [244/1700] Fetching Steam info for App ID 1523570...
# [2025-06-03 17:30:15.365224]     ✗ No valid data for App ID 1523570.
# [2025-06-03 17:30:16.875085]   [245/1700] Fetching Steam info for App ID 908180...
# [2025-06-03 17:30:17.114386]     ✓ Added game 'Space Maze'.
# [2025-06-03 17:30:18.615737]   [246/1700] Fetching Steam info for App ID 688272...
# [2025-06-03 17:30:18.837581]     ✗ Skipped App ID 688272 (type=dlc).
# [2025-06-03 17:30:20.338841]   [247/1700] Fetching Steam info for App ID 2619810...
# [2025-06-03 17:30:20.569718]     ✗ No valid data for App ID 2619810.
# [2025-06-03 17:30:22.071301]   [248/1700] Fetching Steam info for App ID 1638670...
# [2025-06-03 17:30:22.295801]     ✓ Added game 'The Pentest'.
# [2025-06-03 17:30:23.796117]   [249/1700] Fetching Steam info for App ID 3026030...
# [2025-06-03 17:30:23.983768]     ✓ Added game 'Mayalok Alpha v0.1.7'.
# [2025-06-03 17:30:25.485710]   [250/1700] Fetching Steam info for App ID 2299600...
# [2025-06-03 17:30:25.675095]     ✗ Skipped App ID 2299600 (type=demo).
# [2025-06-03 17:30:27.188408]   [251/1700] Fetching Steam info for App ID 1073640...
# [2025-06-03 17:30:27.501701]     ✓ Added game 'JetX Space Edition'.
# [2025-06-03 17:30:29.014886]   [252/1700] Fetching Steam info for App ID 2825690...
# [2025-06-03 17:30:29.192860]     ✗ Skipped App ID 2825690 (type=dlc).
# [2025-06-03 17:30:30.699135]   [253/1700] Fetching Steam info for App ID 1416390...
# [2025-06-03 17:30:31.324743]     ✗ Skipped App ID 1416390 (type=dlc).
# [2025-06-03 17:30:32.825957]   [254/1700] Fetching Steam info for App ID 2263390...
# [2025-06-03 17:30:33.020900]     ✓ Added game 'Lawnmower Game: Ufo Chase'.
# [2025-06-03 17:30:34.531290]   [255/1700] Fetching Steam info for App ID 313630...
# [2025-06-03 17:30:34.838329]     ✓ Added game 'The Solus Project'.
# [2025-06-03 17:30:36.350970]   [256/1700] Fetching Steam info for App ID 1752850...
# [2025-06-03 17:30:36.655316]     ✓ Added game 'Find Match Icons'.
# [2025-06-03 17:30:38.160055]   [257/1700] Fetching Steam info for App ID 627857...
# [2025-06-03 17:30:38.406747]     ✗ Skipped App ID 627857 (type=episode).
# [2025-06-03 17:30:39.908373]   [258/1700] Fetching Steam info for App ID 617290...
# [2025-06-03 17:30:40.099745]     ✓ Added game 'Remnant: From the Ashes'.
# [2025-06-03 17:30:41.604870]   [259/1700] Fetching Steam info for App ID 966400...
# [2025-06-03 17:30:41.852631]     ✓ Added game 'Speaking Simulator'.
# [2025-06-03 17:30:43.356643]   [260/1700] Fetching Steam info for App ID 3377580...
# [2025-06-03 17:30:43.533200]     ✓ Added game 'Cubetory Playtest'.
# [2025-06-03 17:30:45.047983]   [261/1700] Fetching Steam info for App ID 3368510...
# [2025-06-03 17:30:45.351008]     ✓ Added game 'City of Stories: The Professor's Secret Collector's Edition'.
# [2025-06-03 17:30:46.864324]   [262/1700] Fetching Steam info for App ID 1682930...
# [2025-06-03 17:30:47.052689]     ✓ Added game 'Wardens Rising Playtest'.
# [2025-06-03 17:30:48.557795]   [263/1700] Fetching Steam info for App ID 3546700...
# [2025-06-03 17:30:48.744524]     ✓ Added game 'Revive'.
# [2025-06-03 17:30:50.255880]   [264/1700] Fetching Steam info for App ID 496070...
# [2025-06-03 17:30:50.450170]     ✓ Added game 'Geo-Fall'.
# [2025-06-03 17:30:51.957629]   [265/1700] Fetching Steam info for App ID 387160...
# [2025-06-03 17:30:52.131835]     ✗ Skipped App ID 387160 (type=music).
# [2025-06-03 17:30:53.643973]   [266/1700] Fetching Steam info for App ID 1613950...
# [2025-06-03 17:30:53.924090]     ✓ Added game 'Sovereign Tea'.
# [2025-06-03 17:30:55.439787]   [267/1700] Fetching Steam info for App ID 209424...
# [2025-06-03 17:30:55.616609]     ✗ No valid data for App ID 209424.
# [2025-06-03 17:30:57.119275]   [268/1700] Fetching Steam info for App ID 2407550...
# [2025-06-03 17:30:57.673821]     ✓ Added game 'Phantom Thief Effie'.
# [2025-06-03 17:30:59.175854]   [269/1700] Fetching Steam info for App ID 2332580...
# [2025-06-03 17:30:59.365533]     ✓ Added game 'Homeseek Playtest'.
# [2025-06-03 17:31:00.866574]   [270/1700] Fetching Steam info for App ID 3351840...
# [2025-06-03 17:31:01.092490]     ✓ Added game 'Play Twice'.
# [2025-06-03 17:31:02.593666]   [271/1700] Fetching Steam info for App ID 1224896...
# [2025-06-03 17:31:02.806740]     ✗ Skipped App ID 1224896 (type=dlc).
# [2025-06-03 17:31:04.307422]   [272/1700] Fetching Steam info for App ID 1970040...
# [2025-06-03 17:31:04.522797]     ✓ Added game 'Fibula'.
# [2025-06-03 17:31:06.024195]   [273/1700] Fetching Steam info for App ID 3270830...
# [2025-06-03 17:31:06.217712]     ✗ Skipped App ID 3270830 (type=demo).
# [2025-06-03 17:31:07.720486]   [274/1700] Fetching Steam info for App ID 2050980...
# [2025-06-03 17:31:07.915310]     ✓ Added game 'Tim Climpy's Warfair'.
# [2025-06-03 17:31:09.425757]   [275/1700] Fetching Steam info for App ID 1473070...
# [2025-06-03 17:31:09.599863]     ✓ Added game 'Nova Genetics'.
# [2025-06-03 17:31:11.113361]   [276/1700] Fetching Steam info for App ID 1115630...
# [2025-06-03 17:31:11.310190]     ✓ Added game 'Magnetic Daydream'.
# [2025-06-03 17:31:12.820387]   [277/1700] Fetching Steam info for App ID 775380...
# [2025-06-03 17:31:13.001435]     ✗ Skipped App ID 775380 (type=music).
# [2025-06-03 17:31:14.511228]   [278/1700] Fetching Steam info for App ID 2815830...
# [2025-06-03 17:31:14.699729]     ✓ Added game 'Heroic Kingdom: Origins'.
# [2025-06-03 17:31:16.213275]   [279/1700] Fetching Steam info for App ID 3011950...
# [2025-06-03 17:31:16.503290]     ✗ Skipped App ID 3011950 (type=dlc).
# [2025-06-03 17:31:18.005072]   [280/1700] Fetching Steam info for App ID 3159860...
# [2025-06-03 17:31:18.227545]     ✓ Added game 'Feltopia'.
# [2025-06-03 17:31:19.728369]   [281/1700] Fetching Steam info for App ID 597120...
# [2025-06-03 17:31:19.916527]     ✓ Added game 'The Filmmaker - A Text Adventure'.
# [2025-06-03 17:31:21.428990]   [282/1700] Fetching Steam info for App ID 3530630...
# [2025-06-03 17:31:21.605292]     ✓ Added game 'Bless You Again'.
# [2025-06-03 17:31:23.108576]   [283/1700] Fetching Steam info for App ID 2696700...
# [2025-06-03 17:31:23.335748]     ✗ Skipped App ID 2696700 (type=music).
# [2025-06-03 17:31:24.836972]   [284/1700] Fetching Steam info for App ID 3668770...
# [2025-06-03 17:31:25.019851]     ✗ Skipped App ID 3668770 (type=dlc).
# [2025-06-03 17:31:26.532065]   [285/1700] Fetching Steam info for App ID 205070...
# [2025-06-03 17:31:26.777073]     ✓ Added game 'BIT.TRIP VOID'.
# [2025-06-03 17:31:28.278482]   [286/1700] Fetching Steam info for App ID 1720730...
# [2025-06-03 17:31:28.596768]     ✗ Skipped App ID 1720730 (type=demo).
# [2025-06-03 17:31:30.101469]   [287/1700] Fetching Steam info for App ID 395235...
# [2025-06-03 17:31:30.326307]     ✗ Skipped App ID 395235 (type=dlc).
# [2025-06-03 17:31:31.828764]   [288/1700] Fetching Steam info for App ID 2894530...
# [2025-06-03 17:31:32.088206]     ✗ Skipped App ID 2894530 (type=music).
# [2025-06-03 17:31:33.592122]   [289/1700] Fetching Steam info for App ID 562382...
# [2025-06-03 17:31:33.857660]     ✗ Skipped App ID 562382 (type=dlc).
# [2025-06-03 17:31:35.369876]   [290/1700] Fetching Steam info for App ID 2386710...
# [2025-06-03 17:31:35.582374]     ✓ Added game 'Everlasting Abundance'.
# [2025-06-03 17:31:37.083796]   [291/1700] Fetching Steam info for App ID 594230...
# [2025-06-03 17:31:37.317628]     ✓ Added game 'GLITCHED'.
# [2025-06-03 17:31:38.818143]   [292/1700] Fetching Steam info for App ID 2632890...
# [2025-06-03 17:31:39.044752]     ✓ Added game 'WildFront'.
# [2025-06-03 17:31:40.546682]   [293/1700] Fetching Steam info for App ID 2384780...
# [2025-06-03 17:31:40.737459]     ✓ Added game 'Idle Dragon Clicker'.
# [2025-06-03 17:31:42.248034]   [294/1700] Fetching Steam info for App ID 2808020...
# [2025-06-03 17:31:42.501703]     ✗ Skipped App ID 2808020 (type=dlc).
# [2025-06-03 17:31:44.014951]   [295/1700] Fetching Steam info for App ID 216840...
# [2025-06-03 17:31:44.199692]     ✗ No valid data for App ID 216840.
# [2025-06-03 17:31:45.701440]   [296/1700] Fetching Steam info for App ID 2854070...
# [2025-06-03 17:31:45.886525]     ✓ Added game 'Conviction - The Glory Of Kraft -'.
# [2025-06-03 17:31:47.393323]   [297/1700] Fetching Steam info for App ID 963830...
# [2025-06-03 17:31:47.601387]     ✓ Added game 'A Flappy Bird in Real Life'.
# [2025-06-03 17:31:49.102972]   [298/1700] Fetching Steam info for App ID 855790...
# [2025-06-03 17:31:49.302011]     ✗ Skipped App ID 855790 (type=episode).
# [2025-06-03 17:31:50.809078]   [299/1700] Fetching Steam info for App ID 712340...
# [2025-06-03 17:31:51.084899]     ✗ Skipped App ID 712340 (type=dlc).
# [2025-06-03 17:31:52.597076]   [300/1700] Fetching Steam info for App ID 750850...
# [2025-06-03 17:31:52.818976]     ✓ Added game 'The Dream Collector'.
# [2025-06-03 17:31:54.320021]   [301/1700] Fetching Steam info for App ID 925827...
# [2025-06-03 17:31:54.491696]     ✗ Skipped App ID 925827 (type=dlc).
# [2025-06-03 17:31:55.996255]   [302/1700] Fetching Steam info for App ID 2081940...
# [2025-06-03 17:31:56.168025]     ✗ No valid data for App ID 2081940.
# [2025-06-03 17:31:57.682124]   [303/1700] Fetching Steam info for App ID 693601...
# [2025-06-03 17:31:57.957723]     ✗ Skipped App ID 693601 (type=dlc).
# [2025-06-03 17:31:59.471075]   [304/1700] Fetching Steam info for App ID 2192470...
# [2025-06-03 17:31:59.681397]     ✗ Skipped App ID 2192470 (type=dlc).
# [2025-06-03 17:32:01.184726]   [305/1700] Fetching Steam info for App ID 793553...
# [2025-06-03 17:32:01.413058]     ✗ Skipped App ID 793553 (type=dlc).
# [2025-06-03 17:32:02.916525]   [306/1700] Fetching Steam info for App ID 485240...
# [2025-06-03 17:32:03.160293]     ✓ Added game 'Push For Emor'.
# [2025-06-03 17:32:04.661917]   [307/1700] Fetching Steam info for App ID 2475670...
# [2025-06-03 17:32:04.859462]     ✓ Added game 'Starboy Adventures'.
# [2025-06-03 17:32:06.371041]   [308/1700] Fetching Steam info for App ID 2794050...
# [2025-06-03 17:32:06.556593]     ✓ Added game 'Duel with the Devil'.
# [2025-06-03 17:32:08.071094]   [309/1700] Fetching Steam info for App ID 2263991...
# [2025-06-03 17:32:08.298045]     ✗ Skipped App ID 2263991 (type=dlc).
# [2025-06-03 17:32:09.799713]   [310/1700] Fetching Steam info for App ID 209428...
# [2025-06-03 17:32:09.953454]     ✗ No valid data for App ID 209428.
# [2025-06-03 17:32:11.462529]   [311/1700] Fetching Steam info for App ID 237570...
# [2025-06-03 17:32:11.654652]     ✓ Added game 'Penny Arcade's On the Rain-Slick Precipice of Darkness 4'.
# [2025-06-03 17:32:13.165986]   [312/1700] Fetching Steam info for App ID 1000780...
# [2025-06-03 17:32:13.337117]     ✗ Skipped App ID 1000780 (type=dlc).
# ...
# [2025-06-03 18:36:15.743960]   [859/938] Fetching SteamSpy info for App ID 1232010...
# [2025-06-03 18:36:15.815695]     ✓ SteamSpy data appended.
# [2025-06-03 18:36:17.327139]   [860/938] Fetching SteamSpy info for App ID 797010...
# [2025-06-03 18:36:17.493496]     ✓ SteamSpy data appended.
# [2025-06-03 18:36:19.003579]   [861/938] Fetching SteamSpy info for App ID 2803470...
# [2025-06-03 18:36:19.171686]     ✓ SteamSpy data appended.
# [2025-06-03 18:36:20.677906]   [862/938] Fetching SteamSpy info for App ID 1932180...
# [2025-06-03 18:36:20.751656]     ✓ SteamSpy data appended.
# [2025-06-03 18:36:22.261487]   [863/938] Fetching SteamSpy info for App ID 2993690...
# [2025-06-03 18:36:22.434980]     ✓ SteamSpy data appended.
# [2025-06-03 18:36:23.950765]   [864/938] Fetching SteamSpy info for App ID 593100...
# [2025-06-03 18:36:24.133761]     ✓ SteamSpy data appended.
# [2025-06-03 18:36:25.635970]   [865/938] Fetching SteamSpy info for App ID 813630...
# [2025-06-03 18:36:25.800383]     ✓ SteamSpy data appended.
# [2025-06-03 18:36:27.305043]   [866/938] Fetching SteamSpy info for App ID 2981510...
# [2025-06-03 18:36:27.487539]     ✓ SteamSpy data appended.
# [2025-06-03 18:36:28.989368]   [867/938] Fetching SteamSpy info for App ID 1486910...
# [2025-06-03 18:36:29.181471]     ✓ SteamSpy data appended.
# [2025-06-03 18:36:30.689720]   [868/938] Fetching SteamSpy info for App ID 932330...
# [2025-06-03 18:36:30.880001]     ✓ SteamSpy data appended.
# [2025-06-03 18:36:32.389059]   [869/938] Fetching SteamSpy info for App ID 2571180...
# [2025-06-03 18:36:32.570877]     ✓ SteamSpy data appended.
# [2025-06-03 18:36:34.073664]   [870/938] Fetching SteamSpy info for App ID 2983130...
# [2025-06-03 18:36:34.255632]     ✓ SteamSpy data appended.
# [2025-06-03 18:36:35.763800]   [871/938] Fetching SteamSpy info for App ID 2238170...
# [2025-06-03 18:36:35.934164]     ✓ SteamSpy data appended.
# [2025-06-03 18:36:37.445280]   [872/938] Fetching SteamSpy info for App ID 1626610...
# [2025-06-03 18:36:37.596302]     ✓ SteamSpy data appended.
# [2025-06-03 18:36:39.112007]   [873/938] Fetching SteamSpy info for App ID 1403720...
# [2025-06-03 18:36:39.179600]     ✓ SteamSpy data appended.
# [2025-06-03 18:36:40.690445]   [874/938] Fetching SteamSpy info for App ID 2497520...
# [2025-06-03 18:36:40.874123]     ✓ SteamSpy data appended.
# [2025-06-03 18:36:42.385049]   [875/938] Fetching SteamSpy info for App ID 3027590...
# [2025-06-03 18:36:42.566094]     ✓ SteamSpy data appended.
# [2025-06-03 18:36:44.071534]   [876/938] Fetching SteamSpy info for App ID 1423340...
# [2025-06-03 18:36:44.262283]     ✓ SteamSpy data appended.
# [2025-06-03 18:36:45.763210]   [877/938] Fetching SteamSpy info for App ID 519200...
# [2025-06-03 18:36:45.956805]     ✓ SteamSpy data appended.
# [2025-06-03 18:36:47.462888]   [878/938] Fetching SteamSpy info for App ID 1953920...
# [2025-06-03 18:36:47.536692]     ✓ SteamSpy data appended.
# [2025-06-03 18:36:49.044371]   [879/938] Fetching SteamSpy info for App ID 1381200...
# [2025-06-03 18:36:49.226265]     ✓ SteamSpy data appended.
# [2025-06-03 18:36:50.734088]   [880/938] Fetching SteamSpy info for App ID 1696450...
# [2025-06-03 18:36:50.928368]     ✓ SteamSpy data appended.
# [2025-06-03 18:36:52.432356]   [881/938] Fetching SteamSpy info for App ID 3401050...
# [2025-06-03 18:36:52.618931]     ✓ SteamSpy data appended.
# [2025-06-03 18:36:54.123488]   [882/938] Fetching SteamSpy info for App ID 1199540...
# [2025-06-03 18:36:54.294980]     ✓ SteamSpy data appended.
# [2025-06-03 18:36:55.801420]   [883/938] Fetching SteamSpy info for App ID 2184480...
# [2025-06-03 18:36:55.874212]     ✓ SteamSpy data appended.
# [2025-06-03 18:36:57.387758]   [884/938] Fetching SteamSpy info for App ID 2428790...
# [2025-06-03 18:36:57.572513]     ✓ SteamSpy data appended.
# [2025-06-03 18:36:59.076028]   [885/938] Fetching SteamSpy info for App ID 718740...
# [2025-06-03 18:36:59.268813]     ✓ SteamSpy data appended.
# [2025-06-03 18:37:00.774422]   [886/938] Fetching SteamSpy info for App ID 1965290...
# [2025-06-03 18:37:00.940390]     ✓ SteamSpy data appended.
# [2025-06-03 18:37:02.447649]   [887/938] Fetching SteamSpy info for App ID 3538070...
# [2025-06-03 18:37:02.664630]     ✓ SteamSpy data appended.
# [2025-06-03 18:37:04.166258]   [888/938] Fetching SteamSpy info for App ID 3361700...
# [2025-06-03 18:37:04.357722]     ✓ SteamSpy data appended.
# [2025-06-03 18:37:05.869737]   [889/938] Fetching SteamSpy info for App ID 685760...
# [2025-06-03 18:37:06.055585]     ✓ SteamSpy data appended.
# [2025-06-03 18:37:07.568744]   [890/938] Fetching SteamSpy info for App ID 2067000...
# [2025-06-03 18:37:07.761211]     ✓ SteamSpy data appended.
# [2025-06-03 18:37:09.262127]   [891/938] Fetching SteamSpy info for App ID 2787350...
# [2025-06-03 18:37:09.440940]     ✓ SteamSpy data appended.
# [2025-06-03 18:37:10.951420]   [892/938] Fetching SteamSpy info for App ID 2761060...
# [2025-06-03 18:37:11.127549]     ✓ SteamSpy data appended.
# [2025-06-03 18:37:12.640403]   [893/938] Fetching SteamSpy info for App ID 3509860...
# [2025-06-03 18:37:12.801631]     ✓ SteamSpy data appended.
# [2025-06-03 18:37:14.317115]   [894/938] Fetching SteamSpy info for App ID 2691040...
# [2025-06-03 18:37:14.487825]     ✓ SteamSpy data appended.
# [2025-06-03 18:37:15.995707]   [895/938] Fetching SteamSpy info for App ID 1831610...
# [2025-06-03 18:37:16.180648]     ✓ SteamSpy data appended.
# [2025-06-03 18:37:17.682780]   [896/938] Fetching SteamSpy info for App ID 363930...
# [2025-06-03 18:37:17.887900]     ✓ SteamSpy data appended.
# [2025-06-03 18:37:19.389075]   [897/938] Fetching SteamSpy info for App ID 1119760...
# [2025-06-03 18:37:19.565839]     ✓ SteamSpy data appended.
# [2025-06-03 18:37:21.069756]   [898/938] Fetching SteamSpy info for App ID 3404260...
# [2025-06-03 18:37:21.151918]     ✓ SteamSpy data appended.
# [2025-06-03 18:37:22.656316]   [899/938] Fetching SteamSpy info for App ID 1849900...
# [2025-06-03 18:37:22.749263]     ✓ SteamSpy data appended.
# [2025-06-03 18:37:24.252722]   [900/938] Fetching SteamSpy info for App ID 1889010...
# [2025-06-03 18:37:24.419092]     ✓ SteamSpy data appended.
# [2025-06-03 18:37:25.926930]   [901/938] Fetching SteamSpy info for App ID 2452540...
# [2025-06-03 18:37:26.079982]     ✓ SteamSpy data appended.
# [2025-06-03 18:37:27.594100]   [902/938] Fetching SteamSpy info for App ID 3455320...
# [2025-06-03 18:37:27.673700]     ✓ SteamSpy data appended.
# [2025-06-03 18:37:29.185100]   [903/938] Fetching SteamSpy info for App ID 2453660...
# [2025-06-03 18:37:29.356224]     ✓ SteamSpy data appended.
# [2025-06-03 18:37:30.871484]   [904/938] Fetching SteamSpy info for App ID 529140...
# [2025-06-03 18:37:31.106110]     ✓ SteamSpy data appended.
# [2025-06-03 18:37:32.606766]   [905/938] Fetching SteamSpy info for App ID 3297730...
# [2025-06-03 18:37:32.791832]     ✓ SteamSpy data appended.
# [2025-06-03 18:37:34.300444]   [906/938] Fetching SteamSpy info for App ID 2229900...
# [2025-06-03 18:37:34.398510]     ✓ SteamSpy data appended.
# [2025-06-03 18:37:35.902431]   [907/938] Fetching SteamSpy info for App ID 2014420...
# [2025-06-03 18:37:35.984773]     ✓ SteamSpy data appended.
# [2025-06-03 18:37:37.495859]   [908/938] Fetching SteamSpy info for App ID 2421640...
# [2025-06-03 18:37:37.680791]     ✓ SteamSpy data appended.
# [2025-06-03 18:37:39.186852]   [909/938] Fetching SteamSpy info for App ID 3340180...
# [2025-06-03 18:37:39.364243]     ✓ SteamSpy data appended.
# [2025-06-03 18:37:40.866539]   [910/938] Fetching SteamSpy info for App ID 3315670...
# [2025-06-03 18:37:41.066204]     ✓ SteamSpy data appended.
# [2025-06-03 18:37:42.568402]   [911/938] Fetching SteamSpy info for App ID 1290670...
# [2025-06-03 18:37:42.756549]     ✓ SteamSpy data appended.
# [2025-06-03 18:37:44.257893]   [912/938] Fetching SteamSpy info for App ID 2654450...
# [2025-06-03 18:37:44.430615]     ✓ SteamSpy data appended.
# [2025-06-03 18:37:45.941112]   [913/938] Fetching SteamSpy info for App ID 1893890...
# [2025-06-03 18:37:46.025606]     ✓ SteamSpy data appended.
# [2025-06-03 18:37:47.534549]   [914/938] Fetching SteamSpy info for App ID 3695360...
# [2025-06-03 18:37:47.710293]     ✓ SteamSpy data appended.
# [2025-06-03 18:37:49.213750]   [915/938] Fetching SteamSpy info for App ID 1137650...
# [2025-06-03 18:37:49.394457]     ✓ SteamSpy data appended.
# [2025-06-03 18:37:50.895584]   [916/938] Fetching SteamSpy info for App ID 2726920...
# [2025-06-03 18:37:51.064143]     ✓ SteamSpy data appended.
# [2025-06-03 18:37:52.571064]   [917/938] Fetching SteamSpy info for App ID 2582240...
# [2025-06-03 18:37:52.768044]     ✓ SteamSpy data appended.
# [2025-06-03 18:37:54.271373]   [918/938] Fetching SteamSpy info for App ID 1549760...
# [2025-06-03 18:37:54.441181]     ✓ SteamSpy data appended.
# [2025-06-03 18:37:55.944024]   [919/938] Fetching SteamSpy info for App ID 1191420...
# [2025-06-03 18:37:56.123807]     ✓ SteamSpy data appended.
# [2025-06-03 18:37:57.630699]   [920/938] Fetching SteamSpy info for App ID 1925770...
# [2025-06-03 18:37:57.728427]     ✓ SteamSpy data appended.
# [2025-06-03 18:37:59.235460]   [921/938] Fetching SteamSpy info for App ID 1605320...
# [2025-06-03 18:37:59.299498]     ✓ SteamSpy data appended.
# [2025-06-03 18:38:00.815049]   [922/938] Fetching SteamSpy info for App ID 1967150...
# [2025-06-03 18:38:00.999086]     ✓ SteamSpy data appended.
# [2025-06-03 18:38:02.511767]   [923/938] Fetching SteamSpy info for App ID 330020...
# [2025-06-03 18:38:02.718293]     ✓ SteamSpy data appended.
# [2025-06-03 18:38:04.222401]   [924/938] Fetching SteamSpy info for App ID 358090...
# [2025-06-03 18:38:04.449182]     ✓ SteamSpy data appended.
# [2025-06-03 18:38:05.950080]   [925/938] Fetching SteamSpy info for App ID 2328300...
# [2025-06-03 18:38:06.113973]     ✓ SteamSpy data appended.
# [2025-06-03 18:38:07.627142]   [926/938] Fetching SteamSpy info for App ID 3321850...
# [2025-06-03 18:38:07.802111]     ✓ SteamSpy data appended.
# [2025-06-03 18:38:09.307159]   [927/938] Fetching SteamSpy info for App ID 1759550...
# [2025-06-03 18:38:09.506330]     ✓ SteamSpy data appended.
# [2025-06-03 18:38:11.008305]   [928/938] Fetching SteamSpy info for App ID 1721820...
# [2025-06-03 18:38:11.208298]     ✓ SteamSpy data appended.
# [2025-06-03 18:38:12.715750]   [929/938] Fetching SteamSpy info for App ID 1585370...
# [2025-06-03 18:38:12.891047]     ✓ SteamSpy data appended.
# [2025-06-03 18:38:14.396481]   [930/938] Fetching SteamSpy info for App ID 3500...
# [2025-06-03 18:38:14.577731]     ✓ SteamSpy data appended.
# [2025-06-03 18:38:16.088768]   [931/938] Fetching SteamSpy info for App ID 2327660...
# [2025-06-03 18:38:16.247629]     ✓ SteamSpy data appended.
# [2025-06-03 18:38:17.761135]   [932/938] Fetching SteamSpy info for App ID 2347910...
# [2025-06-03 18:38:18.064159]     ✓ SteamSpy data appended.
# [2025-06-03 18:38:19.565678]   [933/938] Fetching SteamSpy info for App ID 3617020...
# [2025-06-03 18:38:19.738129]     ✓ SteamSpy data appended.
# [2025-06-03 18:38:21.251402]   [934/938] Fetching SteamSpy info for App ID 2768920...
# [2025-06-03 18:38:21.424365]     ✓ SteamSpy data appended.
# [2025-06-03 18:38:22.940298]   [935/938] Fetching SteamSpy info for App ID 1047480...
# [2025-06-03 18:38:23.121324]     ✓ SteamSpy data appended.
# [2025-06-03 18:38:24.631575]   [936/938] Fetching SteamSpy info for App ID 2941240...
# [2025-06-03 18:38:24.802366]     ✓ SteamSpy data appended.
# [2025-06-03 18:38:26.310496]   [937/938] Fetching SteamSpy info for App ID 1101420...
# [2025-06-03 18:38:26.497787]     ✓ SteamSpy data appended.
# [2025-06-03 18:38:28.005671]   [938/938] Fetching SteamSpy info for App ID 3351340...
# [2025-06-03 18:38:28.186488]     ✓ SteamSpy data appended.
# [2025-06-03 18:38:29.700974] STEP 4: One-hot encoding 'genres' and 'categories' based on master dataset structure...
# [2025-06-03 18:38:29.790372]   → Master has 1759 rows; this batch has 938 rows.
# [2025-06-03 18:38:29.790372]   → Detected 18 genre labels: ['Action', 'Adventure', 'Animation & Modeling', 'Audio Production', 'Casual']...
# [2025-06-03 18:38:29.790372]   → Detected 36 category labels: ['Captions available', 'Co-op', 'Commentary available', 'Cross-Platform Multiplayer', 'Family Sharing']...
# [2025-06-03 18:38:29.805993]   → One-hot encoding genres for batch...
# [2025-06-03 18:38:29.831159]   → One-hot encoding categories for batch...
# [2025-06-03 18:38:29.900223]   → Dropped raw 'genres' and 'categories' from batch after encoding.
# [2025-06-03 18:38:29.900223]   → Aligning batch columns to master...
# [2025-06-03 18:38:29.900223]     → Added missing batch column 'about_the_game' with zeros.
# [2025-06-03 18:38:29.900223]     → Added missing batch column 'achievements_total' with zeros.
# [2025-06-03 18:38:29.900223]     → Added missing batch column 'background_image' with zeros.
# [2025-06-03 18:38:29.900223]     → Added missing batch column 'coming_soon' with zeros.
# [2025-06-03 18:38:29.900223]     → Added missing batch column 'content_descriptors' with zeros.
# [2025-06-03 18:38:29.900223]     → Added missing batch column 'controller_support' with zeros.
# [2025-06-03 18:38:29.900223]     → Added missing batch column 'detailed_description' with zeros.
# [2025-06-03 18:38:29.900223]     → Added missing batch column 'developer' with zeros.
# [2025-06-03 18:38:29.900223]     → Added missing batch column 'dlc_list' with zeros.
# [2025-06-03 18:38:29.900223]     → Added missing batch column 'first_movie_url' with zeros.
# [2025-06-03 18:38:29.900223]     → Added missing batch column 'first_screenshot_url' with zeros.
# [2025-06-03 18:38:29.900223]     → Added missing batch column 'header_image' with zeros.
# [2025-06-03 18:38:29.900223]     → Added missing batch column 'legal_notice' with zeros.
# [2025-06-03 18:38:29.900223]     → Added missing batch column 'metacritic_url' with zeros.
# [2025-06-03 18:38:29.900223]     → Added missing batch column 'package_groups' with zeros.
# [2025-06-03 18:38:29.900223]     → Added missing batch column 'pc_requirements_min' with zeros.
# [2025-06-03 18:38:29.900223]     → Added missing batch column 'pc_requirements_rec' with zeros.
# [2025-06-03 18:38:29.900223]     → Added missing batch column 'price_currency' with zeros.
# [2025-06-03 18:38:29.900223]     → Added missing batch column 'price_usd_final' with zeros.
# [2025-06-03 18:38:29.900223]     → Added missing batch column 'price_usd_original' with zeros.
# [2025-06-03 18:38:29.900223]     → Added missing batch column 'publisher' with zeros.
# [2025-06-03 18:38:29.900223]     → Added missing batch column 'recommendations' with zeros.
# [2025-06-03 18:38:29.900223]     → Added missing batch column 'support_email' with zeros.
# [2025-06-03 18:38:29.900223]     → Added missing batch column 'support_url' with zeros.
# [2025-06-03 18:38:29.900223]     → Added missing batch column 'supported_languages' with zeros.
# [2025-06-03 18:38:29.900223]     → Added missing batch column 'website' with zeros.
# [2025-06-03 18:38:29.900223]     → Added missing batch column 'platforms_linux.1' with zeros.
# [2025-06-03 18:38:29.915832]     → Added missing batch column 'platforms_mac.1' with zeros.
# [2025-06-03 18:38:29.915832]     → Added missing batch column 'platforms_windows.1' with zeros.
# [2025-06-03 18:38:29.915832]   → Column alignment complete.
# [2025-06-03 18:38:29.915832] STEP 5: Merging new batch into master and logging changes...
# [2025-06-03 18:38:29.929183]   → 924 new unique App IDs to add: [2222400, 2117110, 1570840, 1017630, 3113230, 1305500, 1614850, 2191550, 3088560, 1557470]...
# [2025-06-03 18:38:30.110206]   → Master CSV updated: 1759 → 2683 rows (+924).
# [2025-06-03 18:38:30.110206]   → Merge changes recorded to 'steam_games_merge_log.txt'.
# C:\Users\cmum9\AppData\Local\Temp\ipykernel_17724\586888704.py:201: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined = pd.concat([master_df, new_rows_df], ignore_index=True)
